# %%
import requests
import urllib.request
import pandas as pd

url = 'https://www.abc.net.au/news/good-news/'

html = requests.get(url).content

# %%
from newspaper import Article
url = 'https://www.abc.net.au/news/good-news/'

article = Article(url)
article.download()

# %%
article.parse()

# %%
article.authors
# Out:
# ['Australian Broadcasting Corporation']

# %%
article.text
# Out:
# ''

# %%
import newspaper

# %%
cnn_paper = newspaper.build('https://www.abc.net.au/news/good-news/')

for article in cnn_paper.articles:
    print(article.url)
# Out:
# 466568
# https://www.abc.net.au/news/2020-07-17/human-remains-on-south-west-coast-likely-heng-yi-goh/12468512
# https://www.abc.net.au/news/2020-07-18/self-isolation-in-act-from-victoria-or-sydney-pub-coronavirus/12469388
# https://www.abc.net.au/news/2020-07-18/canberra-pigeons-off-and-racing-as-poo-fertilises-gardens/12446776
# https://www.abc.net.au/news/2020-07-18/giant-freshwater-crayfish-habitat-conservation-program-tasmania/12467212
# https://www.abc.net.au/news/2020-07-18/hope-for-cancer-hotline-reprieve/12468922
# https://www.abc.net.au/news/2020-07-18/nt-coronavirus-quarantine-meet-the-people-in-howard-springs/12468262
# https://www.abc.net.au/news/2020-07-18/palace-letters-reveal-queen-briefed-on-tensions-post-cyclone/12463218
# https://www.abc.net.au/news/2020-03-17/coronavirus-cases-data-reveals-how-covid-19-spreads-in-australia/12060704
# https://www.abc.net.au/news/2020-07-17/florida-governors-trump-loyalty-may-be-driving-coronavirus-rise/12460684
# ...

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(html)
p = soup.find('ul', class_='article-index')
p.h3.text
# Out:
# "\n'Off-roading is no joke': Perth man walks 60km after car gets bogged in WA national park\n"

# %%
p.find_all('h3')
# Out:
# [<h3>
#  <a href="/news/2020-07-17/man-walks-60km-after-bogging-4wd-cape-arid-national-park/12462586">'Off-roading is no joke': Perth man walks 60km after car gets bogged in WA national park</a>
#  </h3>,
#  <h3>
#  <a href="/news/2020-07-17/art-transforms-sterile-hospital-walls-into-colourful-galleries/12461294">Sterile walls transformed into art galleries, brightening the days of staff and patients</a>
#  </h3>,
#  <h3>
#  <a href="/news/2020-07-17/melbourne-couple-swap-city-for-broken-hill-beauty/12461424">Melbourne couple find retirement dream in tranquillity of Broken Hill</a>
#  <span class="media">
#  <span class="photos" title="Photos">(photos)</span>
#  </span>
#  </h3>,
#  <h3>
#  <a href="/news/2020-07-16/marine-area-command-officer-donald-stewart-retires/12463978">'True hero' of marine rescue retires in style after more than 40 years</a>
#  </h3>,
#  <h3>
# ...

# %%
url = ('http://newsapi.org/v2/everything?'
       'q=Good News&'
       'from=2020-07-18&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response = requests.get(url)

response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 322,
#  'articles': [{'source': {'id': 'reuters', 'name': 'Reuters'},
#    'author': 'Reuters Editorial',
#    'title': 'COVID-19 antibody test passes first major trials in UK with 98.6% accuracy - Telegraph - Reuters India',
#    'description': 'British ministers are making plans to distribute millions of free coronavirus antibody tests after a version backed by the UK government passed its first major trials, the Daily Telegraph newspaper reported on Friday.',
#    'url': 'https://in.reuters.com/article/health-coronavirus-britain-testing-idINKCN24J02T',
#    'urlToImage': 'https://s4.reutersmedia.net/resources_v2/images/rcom-default.png',
#    'publishedAt': '2020-07-18T02:59:00Z',
#    'content': '(Reuters) - British ministers are making plans to distribute millions of free coronavirus antibody tests after a version backed by the UK government passed its first major trials, the Daily Telegraph… [+1756 chars]'},
# ...

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 1057,
#  'articles': [{'source': {'id': None, 'name': 'Gizmodo.com'},
#    'author': 'Alyse Stanley',
#    'title': 'Researchers Created an App That Monitors Your Mental Health by Tracking Your Data',
#    'description': 'Even though I appreciate that it’s for a good cause, this app still sounds like something out of Minority Report.Read more...',
#    'url': 'https://gizmodo.com/researchers-created-an-app-that-monitors-mental-health-1844426460',
#    'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/a9yiugxoszjs6qbtwmec.jpg',
#    'publishedAt': '2020-07-18T04:25:00Z',
#    'content': 'Even though I appreciate that its for a good cause, this app still sounds like something out of Minority Report.\r\nResearchers at Dalhousie University in Canada have developed a smartphone app that tr… [+3784 chars]'},
#   {'source': {'id': 'mashable', 'name': 'Mashable'},
# ...

# %%
url = ('http://newsapi.org/v2/everything?'
       'domains=abc.net.au&'
       'from=2020-07-18&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response = requests.get(url)

print(response.json())
# Out:
# {'status': 'ok', 'totalResults': 34, 'articles': [{'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'}, 'author': 'Jake Lapham', 'title': 'Buildings partially collapse after another night of raging seas on the NSW Central Coast', 'description': 'Properties are left significantly damaged after heavy erosion at Wamberal, with residents forcibly evacuated by emergency services.', 'url': 'https://www.abc.net.au/news/2020-07-18/properties-partially-collapse-as-seas-batter-nsw-central-coast/12469400', 'urlToImage': 'https://www.abc.net.au/cm/rimage/12469332-16x9-large.jpg?v=2', 'publishedAt': '2020-07-18T01:06:10Z', 'content': 'Two properties have partially collapsed after heavy erosion at Wamberal on the NSW Central Coast.\r\n<ul><li>Two properties partially collapsed while a third was significantly damaged</li><li>Emergency… [+2013 chars]'}, {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'}, 'author': None, 'title': "The extraordinary lengths producers went to making ABC chi
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/alvinfujito/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from textblob import TextBlob
text = '''
These laptops are horrible but I've seen worse. How about lunch today? The food was okay.
'''

blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# -0.7
# 0.0
# 0.5
# Out:
# -0.7
# 0.0
# 0.5

# %%
from textblob import TextBlob
text = '''
West Ham United are not mathematically safe from relegation but barring something extraordinary their manager David Moyes has completed his second rescue job at the club in two years.
'''

blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.027777777777777773

# %%
from textblob import TextBlob
text = '''
Manchester City's ruthless attacking displays have filled the side with confidence and the firepower at their disposal makes them firm favourites in their FA Cup semi-final clash against Arsenal, defender Kyle Walker has said.
'''

blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# -0.26666666666666666

# %%
url = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'language=en&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response = requests.get(url)

response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 750,
#  'articles': [{'source': {'id': 'bbc-sport', 'name': 'BBC Sport'},
#    'author': 'BBC Sport',
#    'title': 'England v West Indies: Rain set to delay day three - clips, radio & text',
#    'description': "West Indies are set to resume on 32-1 in reply to England's 469-9 on day three of the second Test at Emirates Old Trafford.",
#    'url': 'http://www.bbc.co.uk/sport/live/cricket/51415600',
#    'urlToImage': 'https:////m.files.bbci.co.uk/modules/bbc-morph-sport-seo-meta/1.16.12/images/bbc-sport-logo.png',
#    'publishedAt': '2020-07-18T09:37:28.2738838Z',
#    'content': "It's raining.\r\nAnd when I say raining, I mean rain. Irritating, drizzly, not-moving-any-time-soon weather.\r\nThe weather has no respect for Test cricket, does it?"},
#   {'source': {'id': 'financial-times', 'name': 'Financial Times'},
#    'author': None,
#    'title': '‘We’re all doing it again’ — ‘grumpy’ Melbourne endures second lockdown',
# ...

# %%
text = '''
Corporate ads said Black Lives Matter. But the industry creating them is nearly all white. Companies scrambled after the George Floyd protests picked up speed to get "woke" and show people they cared. The industry they leaned on is nearly all white.
'''

blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# -0.08333333333333333
# 0.05
# 0.0
# 0.05

# %%
text = '''
Kalvin Phillips goes nuts as Leeds players celebrate with fans at Elland Road, while Marcelo Bielsa greets Leeds Uniteds promotion to the Premier League was confirmed on Friday evening and the fans were understandably delighted.\r\nIt has been a long 16-year wait for the supporters since their relegation fr'''


blob = TextBlob(text)
for sentence in blob.sentences:
    print(sentence.sentiment.polarity)
# Out:
# 0.55
# -0.05

# %%
i = 0
while i < len(response.json()['articles']):
    #article_dict['content']
    article_dict = response.json()['articles'][i]
    text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
    
    blob = TextBlob(text_to_be_analysed)
    total_score = 0
    for sentence in blob.sentences:
        total_score += sentence.sentiment.polarity
    print(text_to_be_analysed)
    print("Score: " + str(total_score))
    print("")
    i += 1
# Out:
# England v West Indies: Rain set to delay day three - clips, radio & text. West Indies are set to resume on 32-1 in reply to England's 469-9 on day three of the second Test at Emirates Old Trafford.
# Score: 0.05
#
# ‘We’re all doing it again’ — ‘grumpy’ Melbourne endures second lockdown. News, analysis and comment from the Financial Times, the worldʼs leading global business publication
# Score: 0.0
#
# Hackers stole personal data from up to 8 Twitter accounts. Social media platform says information could include phone numbers and private messages
# Score: 0.016666666666666666
#
# Defence Minister Rajnath Singh visits forward posts in Kupwara. His visit comes amid growing number of ceasefire violations by Pakistan and infiltration bids from across LoC
# Score: 0.0
#
# Villa players devastated with dropped points - Smith. Aston Villa manager Dean Smith says his players are "devastated" with the two points dropped after conceding a late equaliser to draw 1-1 away at Everton.
# ...

# %%
url = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'language=en&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response1 = requests.get(url)


i = 0
while i < len(response1.json()['articles']):
    #article_dict['content']
    article_dict = response1.json()['articles'][i]
    text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
    
    blob = TextBlob(text_to_be_analysed)
    total_score = 0
    for sentence in blob.sentences:
        total_score += sentence.sentiment.polarity
    print(text_to_be_analysed)
    print("Score: " + str(total_score))
    print("")
    i += 1
# Out:
# 42 Beauty Products People Swear Actually Improved Their Skin. From their scalps down to our toes — products reviewers swear changed their skin for the better.
# Score: 0.17222222222222222
#
# Law enforcement officials accused of questionable tactics in Portland. Insight and analysis from journalist and author Andy Ngo and John Yoo, former deputy assistant attorney general.
# Score: -0.475
#
# Kellyanne Conway praises President Trump's handling of COVID crisis, stresses importance of reopening schools. Counselor to the president Kellyanne Conway joins Tammy Bruce with insight on 'Hannity.'
# Score: 0.0
#
# Hackers stole personal data from Twitter accounts. Social media platform says information could include phone numbers and private messages
# Score: 0.016666666666666666
#
# michaelengel/crosstalk. Smalltalk-80 bare metal implementation for the Raspberry Pi - michaelengel/crosstalk
# Score: 0.05
#
# ...

# %%
i = 0
while i < len(response1.json()['articles']):
    #article_dict['content']
    article_dict = response1.json()['articles'][i]
    text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
    
    blob = TextBlob(text_to_be_analysed)
    total_score = 0
    str_score = ''
    for sentence in blob.sentences:
        total_score += sentence.sentiment.polarity
        str_score = str_score + ' ' + str(sentence.sentiment.polarity)
    print(text_to_be_analysed)
    print("Score :"+str_score)
    print("Total Score: " + str(total_score))
    print("")
    i += 1
# Out:
#  increasingly concerned about corporate governance at financial groups
# Score : 0.0 0.0
# Total Score: 0.0
#
# US coronavirus surge: ‘It’s a failure of national leadership’. Sunbelt states suffer a big rise in cases and deaths amid the growing politicisation of issues such as wearing masks
# Score : -0.3166666666666667 0.0
# Total Score: -0.3166666666666667
#
# Iran sends downed Ukrainian plane's black box to France | CBC News. Iran has sent the black box of the Ukrainian passenger jet that its armed forces mistakenly shot down in January to France for reading, an Iranian semi-official news agency said Saturday. Iran accidentally shot down the Boeing 737-800 in January, killing all …
# Score : -0.16666666666666666 -0.16111111111111112 -0.15555555555555559
# Total Score: -0.4833333333333334
#
# Earth Defense Force: World Brothers - Announce Trailer - IGN. Check out the trailer for the upcoming third-person shooter, Earth Defense Force: World Brothers.
#
# ...

# %%
url2 = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'country=au&'
       'language=en&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response2 = requests.get(url2)

# %%
def print_title_description(response):
    i = 0
    while i < len(response.json()['articles']):
        #article_dict['content']
        article_dict = response.json()['articles'][i]
        text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
        
        blob = TextBlob(text_to_be_analysed)
        total_score = 0
        str_score = ''
        num_sentence = 0
        for sentence in blob.sentences:
            total_score += sentence.sentiment.polarity
            str_score = str_score + ' ' + str(sentence.sentiment.polarity)
            num_sentence += 1
        average = total_score/num_sentence
        print(text_to_be_analysed)
        print("Score :"+str_score)
        print("Total Score: " + str(total_score))
        print("Average: " + str(average))
        print("")
        i += 1

# %%
url3 = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'country=au&'
       'category=entertainment&'
       'language=en&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response3 = requests.get(url3)

# %%
print_title_description(response3)
# Out:
# 42 Beauty Products People Swear Actually Improved Their Skin. From their scalps down to our toes — products reviewers swear changed their skin for the better.
# Score : 0.0 0.17222222222222222
# Total Score: 0.17222222222222222
# Average: 0.08611111111111111
#
# Law enforcement officials accused of questionable tactics in Portland. Insight and analysis from journalist and author Andy Ngo and John Yoo, former deputy assistant attorney general.
# Score : -0.5 0.02500000000000001
# Total Score: -0.475
# Average: -0.2375
#
# Kellyanne Conway praises President Trump's handling of COVID crisis, stresses importance of reopening schools. Counselor to the president Kellyanne Conway joins Tammy Bruce with insight on 'Hannity.'
# Score : 0.0 0.0
# Total Score: 0.0
# Average: 0.0
#
# Hackers stole personal data from Twitter accounts. Social media platform says information could include phone numbers and private messages
# Score : 0.0 0.016666666666666666
# Total Score: 0.016666666666666666
# ...

# %%
def print_title_description_combined(response):
    i = 0
    max_score = 0
    str_save = ""
    while i < len(response.json()['articles']):
        #article_dict['content']
        article_dict = response.json()['articles'][i]
        text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
        
        blob = TextBlob(text_to_be_analysed)
        
        score = blob.sentiment.polarity
        if (max_score < score):
            max_score = score
            str_save = text_to_be_analysed
        if score > 0.5:
        
            print(article_dict)
            print("")
            print(text_to_be_analysed)
            print("Score: " + str(score))
            print("")
        i += 1

# %%
print_title_description_combined(response3)
# Out:
# {'source': {'id': None, 'name': 'Mamamia'}, 'author': 'Mamamia Team', 'title': '"I get the irony." Chris Sebastian on stepping out of Guy\'s shadow by going on The Voice. - Mamamia', 'description': 'Chris Sebastian The Voice: The irony of carving out his own identity on the show his  brother Guy Sebastian is a coach on is not lost on Chris Sebastian.', 'url': 'https://www.mamamia.com.au/chris-sebastian-the-voice/', 'urlToImage': 'https://storage.googleapis.com/mamamia-pwa.appspot.com/cms_images/variations/1201x628.7958115183247-141556455554.jpg', 'publishedAt': '2020-07-17T04:17:07Z', 'content': '"It put this reignited fire in my belly, I can\'t resign myself to the fact that I\'m going to sing other people\'s songs. I want to do this, and I can do this, and The Voice is the best way to make tha… [+1422 chars]'}
#
# ...

# %%
print(str_save)
print(max_score)
# Out:
# Literally 32 Things That Are As Functional As Hell. Just a bunch of products that are really, really good at what they do.
# 0.7

# %%
url4 = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'country=au&'
       'category=business&'
       'language=en&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response4 = requests.get(url4)

# %%
print_title_description_combined(response4)
# Out:
# {'source': {'id': None, 'name': '7NEWS.com.au'}, 'author': 'Jenny Ky', 'title': 'Kmart Australia fan shares incredible before-and-after caravan renovation pictures - 7NEWS.com.au', 'description': 'An Aussie mum turned to Kmart to assist with her caravan renovation - and the before and after pictures are amazing.', 'url': 'https://7news.com.au/lifestyle/aussie-mum-shares-her-impressive-caravan-makeover-with-a-little-help-from-kmart-c-1164867', 'urlToImage': 'https://images.s.7news.com.au/publication/C-1164867/e225bfbc8885074eecbc4284fe84fdc92cd6d2bd-16x9-x0y0w1304h734.jpg?imwidth=1024', 'publishedAt': '2020-07-18T07:07:00Z', 'content': 'When it comes to travelling, caravans are quintessentially Australian.\r\nAnd although theyre designed to be practical, they can sometimes be aesthetically lacking.\r\nOne mum has turned to Kmart to assi… [+2184 chars]'}
#
# ...

# %%
url5 = ('http://newsapi.org/v2/top-headlines?'
       'from=2020-07-18&'
       'country=au&'
       'language=en&'
       'pageSize=100&'
       'sortBy=popularity&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response5 = requests.get(url5)
response5.json()
# Out:
#    'title': "Perth woman has 'pony room' in her home after becoming vintage toy collector - 9News",
#    'description': '<p>There is a room in Rene Moore&#x27;s Perth home which is unlike the rest, where bookshelves are brimming not with novels, but with hundreds of whimsical creatures whose tiny eyes follow your every move.</p>',
#    'url': 'https://www.9news.com.au/national/my-little-pony-perth-woman-has-pony-room-in-her-spare-room-serious-nostalgic-toy-collector/eef19bb6-48c0-4dea-a3ad-eca07f85d05e',
#    'urlToImage': 'https://imageresizer.static9.net.au/e3bNGOAjxwZU0-MLG4XzBMTTN84=/1200x628/smart/https%3A%2F%2Fprod.static9.net.au%2Ffs%2F6aa2d112-ac7b-4a1e-8d31-8eee69ba5b1e',
#    'publishedAt': '2020-07-18T04:48:00Z',
#    'content': "Property News:\xa0Personal Space: At home with The Bachelor's Matty J - domain.com.au"},
#   {'source': {'id': 'abc-news-au', 'name': 'ABC News (AU)'},
#    'author': None,
# ...

# %%
print_title_description_combined(response5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-136-0b0e9c98eccd> in <module>
# ----> 1 print_title_description_combined(response5)
#
# <ipython-input-132-6fd30b47493b> in print_title_description_combined(response)
#       6         #article_dict['content']
#       7         article_dict = response.json()['articles'][i]
# ----> 8         text_to_be_analysed = article_dict['title'] + ". " +article_dict['description']
#       9
#      10         blob = TextBlob(text_to_be_analysed)
#
# TypeError: can only concatenate str (not "NoneType") to str

# %%
url6 = ('http://newsapi.org/v2/everything?'
       'from=2020-07-16&'
       'to=2020-07-16&'
       'q=good&'
       'language=en&'
       'pageSize=100&'
       'apiKey=7cbc46d369ec49efba7d4e1bd3df8b1a')

response6 = requests.get(url6)

# %%
response6.json()
# Out:
# desperately to recreate at home. In … [+1917 chars]'},
#   {'source': {'id': 'techcrunch', 'name': 'TechCrunch'},
#    'author': 'Connie Loizos',
#    'title': 'CRV has closed its newest fund with the same amount as its previous fund; “We’re making a statement”',
#    'description': 'CRV, the early-stage venture firm that is this year celebrating its 50th anniversary, has just closed its newest fund with $600 million in capital commitments. The firm asserts that it garnered the pledges entirely during the pandemic, saying it kicked off it…',
#    'url': 'http://techcrunch.com/2020/07/16/crv-has-closed-its-newest-fund-with-the-same-amount-as-its-previous-fund-were-making-a-statement/',
#    'urlToImage': 'https://techcrunch.com/wp-content/uploads/2020/07/CRV.jpeg?w=533',
#    'publishedAt': '2020-07-16T20:15:23Z',
# ...

# %%
response6.json()['articles'][0]
# Out:
# {'source': {'id': 'wired', 'name': 'Wired'},
#  'author': 'Matt Jancer',
#  'title': 'The 15 Best Mac Apps You Should Download Now (2020): Free and Paid',
#  'description': "Apple's macOS is a good desktop operating system, but it's missing some key ingredients. Try these programs to get the most out of your Mac.",
#  'url': 'https://www.wired.com/story/best-mac-apps/',
#  'urlToImage': 'https://media.wired.com/photos/5f0f7e43344cff748529ada0/191:100/w_1280,c_limit/Gear-LEAD---Highland-2---credit-quoteunquote-apps.jpg',
#  'publishedAt': '2020-07-16T12:00:00Z',
#  'content': "The operating system on Apple's computers and laptops, macOS, is stable, efficient, and aesthetically pleasing (the upcoming Big Sur update is especially pretty and clean). But Apple doesn't often li… [+2964 chars]"}
